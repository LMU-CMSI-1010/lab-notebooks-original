# %% [markdown]
# <a href="https://colab.research.google.com/github/LMU-CMSI-1010/lab-notebooks-original/blob/main/Lab04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 04 Take a Walk
# In this lab you will practice using boolean expressions to simulate taking a walk. <!--The number and direction of steps will be determined by random integers—a common approach for programs that seek to simulate some behaviors or systems.-->
# Imagine that you (or a UFO!) are placed in the center of a room. The following cell gives the variables to keep track of your position in that room. The room has a width of 100 ft and you (or your UFO) can move horizontally across the room to the left or the right. The leftmost wall has position 0 and the rightmost wall has position 100. **Run the cell below so you can use these variables.**

# %%
# Use the position variable to keep track of your current position in the room.
position = 50
left_wall = 0
right_wall = 100

# Now we will use asserts with boolean logic to check our position.
# The first one is done for you. Use that pattern to do the last two.
assert(position == 50)
# TODO: Check whether your position is greater than the left wall.
# TODO: Check whether your position is less than the right wall.

# %% [markdown]
# You can assign a boolean expression (which evaluates to True or False) directly to a variable. We've done the first one for you. Follow this example to do the other!

# %%
at_left_wall = position <= left_wall
print('At left wall? ', at_left_wall)

# TODO: Use the above example to make a variable named at_right_wall. Print it.

# %% [markdown]
# Let's say we want to check whether we have reached either the leftmost wall or the rightmost wall of the room (like we did with the UFO) so we can reverse the direction we are moving. Now use the variables you created in the code cell above to define a function that checks whether you have reached a wall.

# %%
# TODO: Define a function that has position as its parameter and returns True if
# you reached a wall and False if not. Note: Best practice for naming boolean
# functions is to use a condition in the name, e.g., is_done or plane_landed

# %% [markdown]
# ## Flip two coins
# In the following cell, we will simulate flipping two coins to determine whether we move left or right. Write a function that uses conditionals to update your current position based on whether the coins are heads or tails. Then test it on all combinations of coins. <!--**use the `flip_coin` function we provided above to simulate two coin flips. Save the results of flipping each coin in separate variables. Add code to check if each toss is heads or tails and save them as boolean variables as indicated in the comments.**-->

# %%
def update_position(position, coin1, coin2):
    # TODO: Move 10 steps to the right if both coins are heads

    # TODO: Move 10 steps to the left if both coins are tails

    # TODO: Move 5 steps to the right if coin1 is heads and coin2 is tails

    # TODO: Move 5 steps to the left if coin1 is tails and coin2 is heads


    return position


coin1 = 'Tails'
coin2 = 'Heads'
print('First toss:', coin1, 'Second toss:', coin2)
# TODO: Call update_position and print our the current position
assert(position == 45) # Do not modify this line!

coin1 = 'Tails'
coin2 = 'Tails'
print('First toss:', coin1, 'Second toss:', coin2)
# TODO: Call update_position and print our the current position
assert(position == 35) # Do not modify this line!

coin1 = 'Heads'
coin2 = 'Heads'
print('First toss:', coin1, 'Second toss:', coin2)
# TODO: Call update_position and print our the current position
assert(position == 45) # Do not modify this line!

coin1 = 'Heads'
coin2 = 'Tails'
print('First toss:', coin1, 'Second toss:', coin2)
# TODO: Call update_position and print our the current position
assert(position == 50) # Do not modify this line!


# TODO: At the very end, call the function you defined in the cell above
# to determine whether we reached a wall.

# %% [markdown]
# ### (Optional) Reflections
# Add a text cell below to answer the following questions:
# 1. What do you feel more confident about after completing this lab?
# 2. What do you feel you can use more help with after completing this lab?
# 3. Do you have any constructive suggestions on how we can help you or improve this lab?

# %% [markdown]
# ### Save your work!
# Go to File -> Save to Drive
# <!--Please save this notebook to your **lab repository** _LMU-CMSI-1010/lab-notebooks-YOURID_-->
